# %%
from glob import glob
from tqdm import tqdm_notebook as tqdm

import numpy as np
import pandas as pd

import torch

from matplotlib import pyplot as plt
import seaborn as sns

from transformers import BertTokenizer, BertModel

pd.set_option("display.max_rows", 300)

# %% [markdown]
# ## e062 の valid を確認する

# %%
trn_df = pd.read_csv('../inputs/origin/train.csv')
display(trn_df.shape, trn_df.head())
# Out:
# (27481, 4)
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
trn_df = trn_df[trn_df.selected_text.notnull()]
trn_df.shape
# Out:
# (27480, 4)

# %%
ckpts = []
for fckpt in glob('../checkpoints/e062/best/*'):
    ckpts.append(torch.load(fckpt))

# %%
ckpts[0].keys()
# Out:
# dict_keys(['fold_num', 'current_epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'val_textIDs', 'val_input_ids', 'val_preds', 'val_labels', 'histories'])

# %%
def _get_predicted_texts(input_ids, y_preds_head, y_preds_tail, tokenizer):
    predicted_texts = []
    for input_id, y_pred_head, y_pred_tail \
            in zip(input_ids, y_preds_head, y_preds_tail):
        pred_label_head = y_pred_head.argmax()
        pred_label_tail = y_pred_tail.argmax()
        predicted_text = tokenizer.decode(
            input_id[pred_label_head:pred_label_tail])
        predicted_texts.append(predicted_text)

    return predicted_texts

# %%
def _get_selected_texts(input_ids, labels_head, labels_tail, tokenizer):
    predicted_texts = []
    for input_id, pred_label_head, pred_label_tail \
            in zip(input_ids, labels_head, labels_tail):
        predicted_text = tokenizer.decode(
            input_id[pred_label_head:pred_label_tail])
        predicted_texts.append(predicted_text)

    return predicted_texts

# %%
import sys
sys.path.append('../')
from tools.tokenizers import myRobertaByteLevelBPETokenizer

tokenizer = myRobertaByteLevelBPETokenizer(   
    vocab_file='../inputs/datasets/roberta/tokenizer/vocab.json',
    merges_file='../inputs/datasets/roberta/tokenizer/merges.txt',
    lowercase=True,
    add_prefix_space=True)

# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
for ckpt in ckpts:
    trn_df = trn_df.set_index('textID')
    predicted_texts = _get_predicted_texts(ckpt['val_input_ids'], ckpt['val_preds'][0],  ckpt['val_preds'][1], tokenizer)
    trn_df.loc[ckpt['val_textIDs'], 'predicted_texts'] = predicted_texts
    trn_df = trn_df.reset_index()
trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                         bullying me...
# 3                                         leave me alone
# 4                                                  ****,
# ...                                                  ...
# 27475                   lost his job and can`t afford it
# 27476                                      i`ve wondered
# 27477                                               good
# 27478                                              worth
# 27479   all this flirting going on - the atg smiles. ...
#
# [27480 rows x 5 columns]

# %%
for ckpt in ckpts:
    trn_df = trn_df.set_index('textID')
    manual_selected_texts = _get_selected_texts(ckpt['val_input_ids'], ckpt['val_labels'][0],  ckpt['val_labels'][1], tokenizer)
    trn_df.loc[ckpt['val_textIDs'], 'manual_selected_text'] = manual_selected_texts
    trn_df = trn_df.reset_index()
trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                         bullying me...
# 3                                         leave me alone
# 4                                                  ****,
# ...                                                  ...
# 27475                   lost his job and can`t afford it
# 27476                                      i`ve wondered
# 27477                                               good
# 27478                                              worth
# 27479   all this flirting going on - the atg smiles. ...
#
#                                     manual_selected_text
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                            bullying me
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                       husband lost
# 27476                                      , don`t force
# 27477                          yay good for both of you.
# 27478                          but it was worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
# [27480 rows x 6 columns]

# %%
trn_df.query('textID == "6cd1ba8680"')
# Out:
#            textID                      text       selected_text sentiment  \
# 19561  6cd1ba8680    Thats charmingly funny  ats charmingly fun  positive
#
#                predicted_texts     manual_selected_text
# 19561   thats charmingly funny   thats charmingly funny

# %%
trn_df[trn_df.manual_selected_text.str.contains('</s>')]
# Out:
# Empty DataFrame
# Columns: [textID, text, selected_text, sentiment, predicted_texts, manual_selected_text]
# Index: []

# %%
trn_df['selected_text_lower'] = trn_df['selected_text'].apply(lambda x: " " + " ".join(x.lower().split()))
trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                         bullying me...
# 3                                         leave me alone
# 4                                                  ****,
# ...                                                  ...
# 27475                   lost his job and can`t afford it
# 27476                                      i`ve wondered
# 27477                                               good
# 27478                                              worth
# 27479   all this flirting going on - the atg smiles. ...
#
#                                     manual_selected_text  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                            bullying me
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                       husband lost
# 27476                                      , don`t force
# 27477                          yay good for both of you.
# 27478                          but it was worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
#                                      selected_text_lower
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                            bullying me
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                             d lost
# 27476                                      , don`t force
# 27477                          yay good for both of you.
# 27478                          but it was worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
# [27480 rows x 7 columns]

# %%
(trn_df.selected_text_lower == trn_df.manual_selected_text).mean()
# Out:
# 0.9046943231441048

# %%
(trn_df.selected_text_lower == trn_df.manual_selected_text).mean()
# Out:
# 0.9031659388646288

# %%
trn_df[(trn_df.selected_text_lower != trn_df.manual_selected_text)].query('sentiment != "neutral"').head(100)
# Out:
#           textID                                               text  \
# 18    af3fed7fc3         is back home now      gonna miss every one
# 27    bdc32ea43c  On the way to Malaysia...no internet access to...
# 32    1c31703aef   If it is any consolation I got my BMI tested ...
# 39    2863f435bd  A little happy for the wine jeje ok it`sm my f...
# 48    3d9d4b0b55  i donbt like to peel prawns, i also dont like ...
# ...          ...                                                ...
# 1061  7048b3a9c0   Nako! Umuulan pa naman!  Anyway, enjoy the bi...
# 1075  7a3840a246  Don`t follow your dreams; chase them.- Richard...
# 1076  3d5c1ed21b   Up is out?  I didn`t get the memo   It looks ...
# 1082  e9c337f756  @_TWEE haha thanks to you that`s my new word f...
# 1095  14c67c535b   Depends on what they want for it....I`ve beco...
#
#                                           selected_text sentiment  \
# 18                                                 onna  negative
# 27                                         .no internet  negative
# 32    well so much for being unhappy for about 10 mi...  negative
# 39                                    A little happy fo  positive
# 48                                         dont like go  negative
# ...                                                 ...       ...
# 1061                                            , enjoy  positive
# 1075                          who I think is very smart  positive
# 1076                                 o   It looks amazi  positive
# 1082                                   thanks to you th  positive
# 1095                            .I`ve become poor again  negative
#
#                  predicted_texts  \
# 18                          miss
# 27    no internet access to twit
# 32                       unhappy
# 39                 love this day
# 48                     dont like
# ...                          ...
# 1061                       enjoy
# 1075                       smart
# 1076                    amazing.
# 1082                      thanks
# 1095      i`ve become poor again
#
#                                    manual_selected_text  \
# 18                                                gonna
# 27                                       ...no internet
# 32     well so much for being unhappy for about 10 m...
# 39                                   a little happy for
# 48                                      dont like going
# ...                                                 ...
# 1061                                            , enjoy
# 1075                          who i think is very smart
# 1076                              memo it looks amazing
# 1082                                 thanks to you that
# 1095                         ....i`ve become poor again
#
#                                     selected_text_lower
# 18                                                 onna
# 27                                         .no internet
# 32     well so much for being unhappy for about 10 m...
# 39                                    a little happy fo
# 48                                         dont like go
# ...                                                 ...
# 1061                                            , enjoy
# 1075                          who i think is very smart
# 1076                                   o it looks amazi
# 1082                                   thanks to you th
# 1095                            .i`ve become poor again
#
# [100 rows x 7 columns]

# %%
trn_df.shape, trn_df[(trn_df.selected_text_lower != trn_df.manual_selected_text)].shape
# Out:
# ((27480, 7), (2619, 7))

# %%
trn_df['manual_and_selected_intersection_len'] = trn_df.apply(lambda row: len(set(row['manual_selected_text'].split()) & set(row['selected_text_lower'].split())), axis=1)
trn_df['manual_and_selected_intersection_len'].value_counts().sort_index()
# Out:
# 0      334
# 1     7211
# 2     2313
# 3     2163
# 4     1983
# 5     1603
# 6     1380
# 7     1176
# 8     1012
# 9      879
# 10     812
# 11     732
# 12     669
# 13     578
# 14     558
# 15     504
# 16     470
# 17     454
# 18     435
# 19     395
# 20     414
# 21     335
# 22     317
# 23     289
# 24     211
# 25     114
# 26      77
# 27      40
# 28      14
# 29       8
# Name: manual_and_selected_intersection_len, dtype: int64

# %%
trn_df['manual_and_selected_tokenized_intersection_len'] = trn_df.apply(lambda row: len(set(tokenizer.encode(' '.join(row['manual_selected_text'].split()), add_special_tokens=False).ids) & set(tokenizer.encode(' '.join(row['selected_text_lower'].split()), add_special_tokens=False).ids)), axis=1)
trn_df['manual_and_selected_tokenized_intersection_len'].value_counts().sort_index()
# Out:
# 0       66
# 1     5172
# 2     2825
# 3     1859
# 4     1746
# 5     1628
# 6     1335
# 7     1152
# 8     1027
# 9      961
# 10     800
# 11     701
# 12     684
# 13     649
# 14     584
# 15     502
# 16     514
# 17     477
# 18     445
# 19     452
# 20     380
# 21     361
# 22     375
# 23     354
# 24     368
# 25     317
# 26     307
# 27     278
# 28     243
# 29     238
# 30     165
# 31     128
# 32     134
# 33      88
# 34      56
# 35      29
# 36      25
# 37      16
# 38      15
# 39       8
# 40       8
# 41       5
# 42       3
# Name: manual_and_selected_tokenized_intersection_len, dtype: int64

# %%
trn_df.query('manual_and_selected_tokenized_intersection_len == 0').head(100)
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 309    a54d3c2825              I know   It was worth a shot, though!
# 491    ee9df322d1                  Sorry, we`ll try to keep it down.
# 808    31fa81e0ae    Yes, you should go see Star Trek!  It`s sooo...
# 1727   795de6c2f5   ooh ouch!   lovely weather but ****! cover up...
# 1797   c4ffb519a5  I don`t feel any pressure right now...    Happ...
# 2597   95593ecedb   Cool Sound!! Luv 'Drama', 'Love Game' doesn`t...
# 2786   acfbac049f     Sure!  My entire blogroll is terribly updat...
# 3324   ee5eb5337b  Heading to the gym.  The group of guys that US...
# 3503   d5b33ff5f4    it was just true  and you do cause me to hav...
# 4324   f5fb5b2236   I know   Guess I was hoping they`d revitalize...
# 4343   cecd8f1042     good point!! Mine is on its way. How did he...
# 4763   43e6d9aeaa   Well I guess they think of everything   Thank...
# 5435   780c673bca  going out for the good ol` `soak` tonight for ...
# 6376   fbaace1664  Passing out  early  after the  river sounds am...
# 6803   43887b9d65   Haha.. Hey you should check out   Love her/hi...
# 6832   78a714e8bb  Don`t know what the heck to do with the space ...
# 7135   a4ba901f22    just listened to the songs on your myspace. ...
# 7768   972c0874b2    Oh no matey, did you get ill?  It would be a...
# 8728   12f21c8f19   star wars ............ is **** BOO??? i wanna...
# 9062   3e775363a1         We can`t even call you from belgium  sucks
# 10183  1e0fefceaf  _tall_blonde   ~~Hello~~~  and thanks for the ...
# 10967  f6b45a61d5   need to get an intel based mac 1st   but this...
# 11158  a65d96c8c9   Yes, dahling... you are definitely one awesom...
# 11479  f2eb0b5e90   hi hun!!  i really loved your tutorial yday! ...
# 11807  96ff964db0  4 hours of sleep, a migraine, again? What is w...
# 12137  ce0025d376   ack, no can see  either.  and weird, these tw...
# 12186  1950e8ff99   I`ll check it out!  Thanks  and good luck wit...
# 12355  e5d31d8d38   i have tried the Teriyaki - no cookie tho!  w...
# 12404  df398a774e    alright...I`m going to get off comp now, go ...
# 12415  d2a221697e    Yes,  and I hope the show I promoted was cle...
# 12521  f3a526931d  Saying goodbye to a good trusted friend today....
# 12731  633e9e07ff   i did and i feel great....   but i still miss...
# 12842  f9766da79f  Hello to all my new followers..    say hi @ me...
# 13226  d0ecfc8c28     you guys were absolutely amazing tonight, a...
# 13802  8b4a1efb7e  forgot she had a Twitter account.    Happy Mot...
# 13906  c573f1463f  Night Night Everyone.    HAPPY MOTHERS DAY to ...
# 14171  c155efab1b              Hey Honey  Bunny here  big bunny hugs
# 14256  75bf000837   can`t! need to work on overtime project at lu...
# 14427  23b8ac0826   ohh right; but it turned her curve into a rig...
# 15009  00f02e92d6   Thank you - If you like please leave a commen...
# 15206  4b3fd4ec22     Last day at DMA over!     a million sad faces.
# 17681  f1dadac45b    Welcome to Twitter  It`s really cool that yo...
# 18907  466f707c18   i hope so  I KNOW WOO! haha 2 times  it was e...
# 21375  eaf2942ee8   bud light?!?!?!  up in Massachusetts and no B...
# 21538  142f9472fc  Meeting up with Karen and the boys for some dr...
# 21982  4c279acff6   why? i enjoy fancy meals on my own smtimes, t...
# 22279  d635eff196    i just saw your performance on the ellen sho...
# 22863  0e0ea93f6e     well, I couldn`t get a real clear shot, but...
# 23526  debbd12acd   I hear you   Any time earlier than 11am is ju...
# 23616  1fd79e3de5     Just saw it tonight as well... Great movie!...
# 23679  cd5989172a   Sounds painful   Sorry you got hurt.. And may...
# 23745  b91963e312     Know I`m not the only one.  Just harder on me.
# 24025  57a498a841        yahyan:  iaaaaaaaaaaaaan, i was just joking
# 24504  db01ffbc9f   http://twitpic.com/4hsd2 - Weheyyyy   We give...
# 24752  99f9b82224                   Happy mother`s day to your moms.
# 24928  09d0f8f088   two macaroons go into a bar....one says oh yo...
# 25103  8a297e9460   aw poor u   DON`T let her get 2 u just ignore...
# 25283  2e3afc2394    gutted i miss that! the one night i try 2 le...
# 25498  d93bc4e903  I definitely missed listening to The Spill Can...
# 25759  61306b5f1e  @_Bella_Cullen13  _Cullen26  _Cullen10  These ...
# 26829  24d37f9ba7                       my bracelet broke today too.
# 26975  7b11a02202     We were all set to get a room last Saturday...
# 27120  a11ddb9e58  The geographY was an exam today!But turned out...
# 27208  30a1e8c2b4  Guys (    ) I know! My ability to read time te...
# 27385  e149ebd3a1  #vwll2009 Would one of the VWLLers want to add...
#
#       selected_text sentiment  \
# 18             onna  negative
# 309         as wort  positive
# 491            Sorr  negative
# 808           ch fu  positive
# 1727          lovel  positive
# 1797           Happ  positive
# 2597         ish Go  positive
# 2786     uld motiva  positive
# 3324          ly sa  negative
# 3503        ng dirt  negative
# 4324       as hopin  positive
# 4343            goo  positive
# 4763      g   Thank  positive
# 5435            ing  positive
# 6376      ds amazin  positive
# 6803            Lov  positive
# 6832           Bore  negative
# 7135         ly goo  positive
# 7768         it mea  negative
# 8728              l  positive
# 9062        m  suck  negative
# 10183      nd thank  positive
# 10967      ly bette  positive
# 11158        ng lov  positive
# 11479        he bes  positive
# 11807           hat  negative
# 12137       nd weir  negative
# 12186        nd goo  positive
# 12355       as grea  positive
# 12404           ave  positive
# 12415       as clea  positive
# 12521         goodb  positive
# 12731        ll mis  negative
# 12842        ts nic  positive
# 13226     ly amazin  positive
# 13802          Happ  positive
# 13906          HAPP  positive
# 14171          unny  positive
# 14256           Sor  negative
# 14427         thank  positive
# 15009       er grea  positive
# 15206           ion  negative
# 17681        ly coo  positive
# 18907    as excitin  positive
# 21375           ht?  positive
# 21538            fo  negative
# 21982           joy  positive
# 22279    ere AMAZIN  positive
# 22863        he bes  positive
# 23526        st mea  negative
# 23616       .. Grea  positive
# 23679          Sorr  negative
# 23745      st harde  negative
# 24025      st jokin  positive
# 24504      ve thank  positive
# 24752          Happ  positive
# 24928            wo  positive
# 25103      st ignor  negative
# 25283       re tire  negative
# 25498         misse  negative
# 25759        ls  lo  positive
# 26829       elet br  negative
# 26975     or missin  negative
# 27120     ry nervou  negative
# 27208      es faile  negative
# 27385  ch appreciat  positive
#
#                                          predicted_texts manual_selected_text  \
# 18                                                  miss                gonna
# 309                                                worth            was worth
# 491                                               sorry,                sorry
# 808                                it`s sooooo much fun!             much fun
# 1727                                              lovely               lovely
# 1797                                               happy                happy
# 2597                                                cool            wish good
# 2786                                            motivate       could motivate
# 3324                               makes me terribly sad         terribly sad
# 3503                                      dirty thoughts         having dirty
# 4324                                              hoping           was hoping
# 4343                                        good point!!                 good
# 4763                                      thanks so much    everything thanks
# 5435                                             in love                going
# 6376                                            amazing.       sounds amazing
# 6803                                                love                 love
# 6832                                              bored.                bored
# 7135                                         really good          really good
# 7768                              it would be a bit mean             bit mean
# 8728                                                 lol               school
# 9062                                               sucks            ium sucks
# 10183                                             thanks           and thanks
# 10967                                             better      probably better
# 11158                                            awesome         sending love
# 11479   i really loved your tutorial yday! soooo much...             the best
# 11807                                       hate my life                 what
# 12137                 ack, no can see either. and weird,            and weird
# 12186                                             thanks             and good
# 12355                                     all was great!            was great
# 12404                                          have fun!                 have
# 12415                                               hope            was clean
# 12521                                               good              goodbye
# 12731                                         miss it...           still miss
# 12842                                           its nice             its nice
# 13226                                            amazing   absolutely amazing
# 13802                                              happy                happy
# 13906                                              happy                happy
# 14171                                               hugs                bunny
# 14256                                             sorry!                sorry
# 14427               i just like her better curvey thanks               thanks
# 15009   thank you - if you like please leave a commen...        another great
# 15206                                         sad faces.              million
# 17681                                   it`s really cool          really cool
# 18907                                           exciting         was exciting
# 21375                                              njoy!              light?!
# 21538                                               ****                  for
# 21982                                              enjoy                enjoy
# 22279   you were amazing and have such a wonderful vo...         were amazing
# 22863                                               best             the best
# 23526                                              mean!            just mean
# 23616                                      great movie!!            ... great
# 23679                                     sounds painful                sorry
# 23745                                             harder          just harder
# 24025                                             joking          just joking
# 24504                                             thanks          give thanks
# 24752                                              happy                happy
# 24928                                                wow                  two
# 25103                                            aw poor          just ignore
# 25283                                             gutted           were tired
# 25498                                             missed               missed
# 25759                                               love           girls love
# 26829                                              broke       bracelet broke
# 26975     i can`t apologise enough for missing out deccy          for missing
# 27120                                         nervous...         very nervous
# 27208                                            failed!       devices failed
# 27385                              would much appreciate      much appreciate
#
#       selected_text_lower  manual_and_selected_intersection_len  \
# 18                   onna                                     0
# 309               as wort                                     0
# 491                  sorr                                     0
# 808                 ch fu                                     0
# 1727                lovel                                     0
# 1797                 happ                                     0
# 2597               ish go                                     0
# 2786           uld motiva                                     0
# 3324                ly sa                                     0
# 3503              ng dirt                                     0
# 4324             as hopin                                     0
# 4343                  goo                                     0
# 4763              g thank                                     0
# 5435                  ing                                     0
# 6376            ds amazin                                     0
# 6803                  lov                                     0
# 6832                 bore                                     0
# 7135               ly goo                                     0
# 7768               it mea                                     0
# 8728                    l                                     0
# 9062               m suck                                     0
# 10183            nd thank                                     0
# 10967            ly bette                                     0
# 11158              ng lov                                     0
# 11479              he bes                                     0
# 11807                 hat                                     0
# 12137             nd weir                                     0
# 12186              nd goo                                     0
# 12355             as grea                                     0
# 12404                 ave                                     0
# 12415             as clea                                     0
# 12521               goodb                                     0
# 12731              ll mis                                     0
# 12842              ts nic                                     0
# 13226           ly amazin                                     0
# 13802                happ                                     0
# 13906                happ                                     0
# 14171                unny                                     0
# 14256                 sor                                     0
# 14427               thank                                     0
# 15009             er grea                                     0
# 15206                 ion                                     0
# 17681              ly coo                                     0
# 18907          as excitin                                     0
# 21375                 ht?                                     0
# 21538                  fo                                     0
# 21982                 joy                                     0
# 22279          ere amazin                                     0
# 22863              he bes                                     0
# 23526              st mea                                     0
# 23616             .. grea                                     0
# 23679                sorr                                     0
# 23745            st harde                                     0
# 24025            st jokin                                     0
# 24504            ve thank                                     0
# 24752                happ                                     0
# 24928                  wo                                     0
# 25103            st ignor                                     0
# 25283             re tire                                     0
# 25498               misse                                     0
# 25759               ls lo                                     0
# 26829             elet br                                     0
# 26975           or missin                                     0
# 27120           ry nervou                                     0
# 27208            es faile                                     0
# 27385        ch appreciat                                     0
#
#        manual_and_selected_tokenized_intersection_len
# 18                                                  0
# 309                                                 0
# 491                                                 0
# 808                                                 0
# 1727                                                0
# 1797                                                0
# 2597                                                0
# 2786                                                0
# 3324                                                0
# 3503                                                0
# 4324                                                0
# 4343                                                0
# 4763                                                0
# 5435                                                0
# 6376                                                0
# 6803                                                0
# 6832                                                0
# 7135                                                0
# 7768                                                0
# 8728                                                0
# 9062                                                0
# 10183                                               0
# 10967                                               0
# 11158                                               0
# 11479                                               0
# 11807                                               0
# 12137                                               0
# 12186                                               0
# 12355                                               0
# 12404                                               0
# 12415                                               0
# 12521                                               0
# 12731                                               0
# 12842                                               0
# 13226                                               0
# 13802                                               0
# 13906                                               0
# 14171                                               0
# 14256                                               0
# 14427                                               0
# 15009                                               0
# 15206                                               0
# 17681                                               0
# 18907                                               0
# 21375                                               0
# 21538                                               0
# 21982                                               0
# 22279                                               0
# 22863                                               0
# 23526                                               0
# 23616                                               0
# 23679                                               0
# 23745                                               0
# 24025                                               0
# 24504                                               0
# 24752                                               0
# 24928                                               0
# 25103                                               0
# 25283                                               0
# 25498                                               0
# 25759                                               0
# 26829                                               0
# 26975                                               0
# 27120                                               0
# 27208                                               0
# 27385                                               0

# %%
trn_df.to_csv('../inputs/nes_info/v3_dataset_trn_df.csv', index=False)

# %% [markdown]
# ## debug

# %%
row = trn_df.query('textID == "6cd1ba8680"').iloc[0]

# %%
text = " " + " ".join(row['text'].split())
text_output = tokenizer.encode_plus(
    text=text,
    # text_pair=None,
    # text_pair=f"[{row['sentiment']}]",
    text_pair=row['sentiment'],
    add_special_tokens=True,
    max_length=125,
    pad_to_max_length=True,
    return_tensor='pt',
    return_token_type_ids=False,
    return_attention_mask=True,
    return_special_tokens_mask=True,
)
row['input_ids'] = text_output['input_ids']
row['attention_mask'] = text_output['attention_mask']
row['special_tokens_mask'] = text_output['special_tokens_mask']

if 'selected_text' not in row:
    row['selected_text'] = ''
    row['labels_head'] = -1
    row['labels_tail'] = -1
#    return row

text = " " + " ".join(row['selected_text'].split())
selected_text_output = tokenizer.encode_plus(
    text=text,
    text_pair=None,
    add_special_tokens=False,
    max_length=125,
    pad_to_max_length=False,
    return_tensor='pt',
    return_token_type_ids=False,
    return_attention_mask=False,
)

# allign labels for segmentation
input_ids = text_output['input_ids']
sel_input_ids = selected_text_output['input_ids']
# 1 start なのは、先頭の token をスルーするため
matched_cnt = len([i for i in input_ids[1:1 + len(sel_input_ids)]
                   if i in sel_input_ids])
best_matched_cnt = matched_cnt
best_matched_i = 1
# for i in range(0, len(input_ids)):
# 1 start なのは、先頭の token をスルーするため
for i in range(1, len(input_ids) - len(sel_input_ids)):
    head_input_id_i = input_ids[i]
    tail_input_id_i = input_ids[i + len(sel_input_ids)]
    if head_input_id_i in sel_input_ids:
        matched_cnt -= 1
    if tail_input_id_i in sel_input_ids:
        matched_cnt += 1
    if matched_cnt < 0:
        raise Exception('invalid logic')

    if best_matched_cnt < matched_cnt:
        best_matched_cnt = matched_cnt
        best_matched_i = i + 1   # 抜いた時の話なので
    if best_matched_cnt == len(sel_input_ids):
        break

row['labels_head'] = best_matched_i
row['labels_tail'] = best_matched_i + len(sel_input_ids)

# %%
row['text']
# Out:
# '  Thats charmingly funny'

# %%
row['selected_text']
# Out:
# 'ats charmingly fun'

# %%
selected_text_output['input_ids']
# Out:
# [23, 29, 18452, 352, 1531]

# %%
" " + " ".join(row['selected_text'].split())
# Out:
# ' ats charmingly fun'

# %%
tokenizer.encode(" " + " ".join(row['selected_text'].split())).ids
# Out:
# [23, 29, 18452, 352, 1531]

# %%
tokenizer.encode(" " + " ".join(row['text'].split())).ids
# Out:
# [45365, 18452, 352, 6269]

# %%
tokenizer.decode()

# %% [markdown]
# ## tokenizer 確認

# %%
import sys
sys.path.append('../')
from tools.tokenizers import myRobertaByteLevelBPETokenizer

my_tokenizer = myRobertaByteLevelBPETokenizer(   
    vocab_file='../inputs/datasets/roberta/tokenizer/vocab.json',
    merges_file='../inputs/datasets/roberta/tokenizer/merges.txt',
    lowercase=True,
    add_prefix_space=True)

# %%
my_tokenizer.decode(ckpt['val_input_ids'][0][1:11])
# Out:
# ' i`d have responded, if i were going'

# %%
def jaccard(str1, str2):
    a = set(str1.lower().split())
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
temp_jac = 0
for i, row in trn_df.iterrows():
    temp_jac += jaccard(row['selected_text'], row['predicted_texts'])

# %%
temp_jac / len(trn_df)
# Out:
# 0.44581498228808364

# %% [markdown]
# ## 改善の必要あり
#  - decode すると違う形式になってしまう
#  - selected_text を encode -> decode して形式が変わるパターンを除去する後処理が必要そう

# %%
trn_df.loc[0]
# Out:
# textID                                                         cb774db0d1
# text                                  I`d have responded, if I were going
# selected_text                         I`d have responded, if I were going
# sentiment                                                         neutral
# predicted_texts         i ` d have responded, if i were going [SEP] [PAD]
# manual_selected_text    i ` d have responded, if i were going [SEP] [PAD]
# Name: 0, dtype: object

# %%
jaccard(trn_df.loc[0]['selected_text'], trn_df.loc[0]['predicted_texts'][:-12])
# Out:
# 0.6666666666666666

# %%
trn_df.loc[0]['selected_text'][4:], trn_df.loc[0]['predicted_texts'][6:-12]
# Out:
# ('have responded, if I were going', 'have responded, if i were going')
