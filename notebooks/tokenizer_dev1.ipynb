# %%
import gc

from tqdm import tqdm_notebook as tqdm

import numpy as np
import pandas as pd

import torch

from matplotlib import pyplot as plt
import seaborn as sns

from transformers import BertTokenizer, BertModel, RobertaTokenizer

pd.set_option('display.max_rows', 600)

# %% [markdown]
# ## e005 の valid を確認する

# %%
trn_df = pd.read_csv('../inputs/origin/train.csv')
trn_df = trn_df[trn_df.selected_text.notnull()]
display(trn_df.shape, trn_df.head())
# Out:
# (27480, 4)
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
ls ../checkpoints/e007/best_for_analysis/
# Out:
# epoch_2_1.85479_-1.00000_0.71094_checkpoint.pth
# epoch_2_1.85522_-1.00000_0.70647_checkpoint.pth
# epoch_3_1.85356_-1.00000_0.70685_checkpoint.pth
# epoch_3_1.88161_-1.00000_0.70257_checkpoint.pth
# epoch_3_1.89511_-1.00000_0.70562_checkpoint.pth

# %%
from glob import glob

pths = glob('../checkpoints/e007/best_for_analysis/*')
# pths = glob('../checkpoints/e007/best/*')

# %%
ckpts = {}

for i, filepath in enumerate(pths):
    ckpts[i] = torch.load(filepath)

# %%
ckpts[0].keys()
# Out:
# dict_keys(['fold_num', 'current_epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'val_textIDs', 'val_input_ids', 'val_preds', 'val_labels', 'histories'])

# %%
def _get_predicted_texts(input_ids, y_preds_head, y_preds_tail, tokenizer):
    predicted_texts = []
    for input_id, y_pred_head, y_pred_tail \
            in zip(input_ids, y_preds_head, y_preds_tail):
        pred_label_head = y_pred_head.argmax()
        pred_label_tail = y_pred_tail.argmax()
        predicted_text = tokenizer.decode(
            input_id[pred_label_head:pred_label_tail])
        predicted_texts.append(predicted_text)

    return predicted_texts

# %%
def _get_selected_texts(input_ids, labels_head, labels_tail, tokenizer):
    predicted_texts = []
    for input_id, pred_label_head, pred_label_tail \
            in zip(input_ids, labels_head, labels_tail):
        predicted_text = tokenizer.decode(
            input_id[pred_label_head:pred_label_tail])
        predicted_texts.append(predicted_text)

    return predicted_texts

# %%
def _get_unknown_nums(input_ids, labels_head, labels_tail, tokenizer):
    unknown_nums = []
    for input_id, pred_label_head, pred_label_tail \
            in zip(input_ids, labels_head, labels_tail):
        unknown_nums.append((np.asarray(input_id) == 3).sum())

    return unknown_nums

# %%
import sys
sys.path.append('../')
from tools.tokenizers import myRobertaByteLevelBPETokenizer

tokenizer = myRobertaByteLevelBPETokenizer(   
    vocab_file='../inputs/datasets/roberta/tokenizer/vocab.json',
    merges_file='../inputs/datasets/roberta/tokenizer/merges.txt',
    lowercase=True,
    add_prefix_space=True)

# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
trn_df = trn_df.set_index('textID')

for ckpt_key in ckpts:
    ckpt = ckpts[ckpt_key]
    predicted_texts = _get_predicted_texts(ckpt['val_input_ids'], ckpt['val_preds'][0],  ckpt['val_preds'][1], tokenizer)
    trn_df.loc[ckpt['val_textIDs'], 'predicted_texts'] = predicted_texts

trn_df = trn_df.reset_index()

trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                               bullying
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                               lost
# 27476                                      i`ve wondered
# 27477                                           yay good
# 27478                                     worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
# [27480 rows x 5 columns]

# %%
trn_df = trn_df.set_index('textID')

for ckpt_key in ckpts:
    ckpt = ckpts[ckpt_key]
    manual_selected_texts = _get_selected_texts(ckpt['val_input_ids'], ckpt['val_labels'][0],  ckpt['val_labels'][1], tokenizer)
    trn_df.loc[ckpt['val_textIDs'], 'manual_selected_text'] = manual_selected_texts
    
trn_df = trn_df.reset_index()

trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                               bullying
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                               lost
# 27476                                      i`ve wondered
# 27477                                           yay good
# 27478                                     worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
#                                     manual_selected_text
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                            bullying me
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                       husband lost
# 27476                                      , don`t force
# 27477                          yay good for both of you.
# 27478                          but it was worth it ****.
# 27479  <s> all this flirting going on - the atg smile...
#
# [27480 rows x 6 columns]

# %%
trn_df = trn_df.set_index('textID')

for ckpt_key in ckpts:
    ckpt = ckpts[ckpt_key]
    unknown_nums = _get_unknown_nums(ckpt['val_input_ids'], ckpt['val_labels'][0],  ckpt['val_labels'][1], tokenizer)
    trn_df.loc[ckpt['val_textIDs'], 'unknown_nums'] = unknown_nums
    
trn_df = trn_df.reset_index()

trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                               bullying
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                               lost
# 27476                                      i`ve wondered
# 27477                                           yay good
# 27478                                     worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
#                                     manual_selected_text  unknown_nums
# 0                    i`d have responded, if i were going           0.0
# 1                                               sooo sad           0.0
# 2                                            bullying me           0.0
# 3                                         leave me alone           0.0
# 4                                          sons of ****,           0.0
# ...                                                  ...           ...
# 27475                                       husband lost           0.0
# 27476                                      , don`t force           0.0
# 27477                          yay good for both of you.           0.0
# 27478                          but it was worth it ****.           0.0
# 27479  <s> all this flirting going on - the atg smile...           0.0
#
# [27480 rows x 7 columns]

# %%
# no unkonwn
trn_df.unknown_nums.value_counts()
# Out:
# 0.0    27480
# Name: unknown_nums, dtype: int64

# %%
print(trn_df['selected_text'].isnull().sum())
trn_df['selected_text'] = trn_df['selected_text'].fillna('')
print(trn_df['selected_text'].isnull().sum())

trn_df['selected_text_lower'] = trn_df.selected_text.apply(lambda x: ' ' + x.lower())
# Out:
# 0
# 0

# %%
trn_df['selected_text_lower'] = trn_df['selected_text_lower'].apply(lambda x: ' ' + ' '.join(x.split()))
trn_df = trn_df[trn_df['manual_selected_text'].notnull()]
trn_df['manual_selected_text'] = trn_df['manual_selected_text'].apply(lambda x: ' ' + ' '.join(x.split()))

# %%
trn_df['manual_equal_selected'] = (trn_df['manual_selected_text'] == trn_df['selected_text_lower']).values
trn_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27475                                             d lost  negative
# 27476                                      , don`t force  negative
# 27477                          Yay good for both of you.  positive
# 27478                         But it was worth it  ****.  positive
# 27479  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                          predicted_texts  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                               bullying
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                               lost
# 27476                                      i`ve wondered
# 27477                                           yay good
# 27478                                     worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
#                                     manual_selected_text  unknown_nums  \
# 0                    i`d have responded, if i were going           0.0
# 1                                               sooo sad           0.0
# 2                                            bullying me           0.0
# 3                                         leave me alone           0.0
# 4                                          sons of ****,           0.0
# ...                                                  ...           ...
# 27475                                       husband lost           0.0
# 27476                                      , don`t force           0.0
# 27477                          yay good for both of you.           0.0
# 27478                          but it was worth it ****.           0.0
# 27479   <s> all this flirting going on - the atg smil...           0.0
#
#                                      selected_text_lower  \
# 0                    i`d have responded, if i were going
# 1                                               sooo sad
# 2                                            bullying me
# 3                                         leave me alone
# 4                                          sons of ****,
# ...                                                  ...
# 27475                                             d lost
# 27476                                      , don`t force
# 27477                          yay good for both of you.
# 27478                          but it was worth it ****.
# 27479   all this flirting going on - the atg smiles. ...
#
#        manual_equal_selected
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# ...                      ...
# 27475                  False
# 27476                   True
# 27477                   True
# 27478                   True
# 27479                  False
#
# [27480 rows x 9 columns]

# %%
trn_df.manual_equal_selected.value_counts()
# Out:
# True     24830
# False     2650
# Name: manual_equal_selected, dtype: int64

# %%
trn_df['num_intersection'] = trn_df.apply(lambda row: len(set(row['manual_selected_text'].split()) & set(row['selected_text_lower'].split())), axis=1)

# %%
trn_df['num_intersection'].value_counts().sort_index()
# Out:
# 0      500
# 1     7126
# 2     2331
# 3     2134
# 4     1968
# 5     1592
# 6     1367
# 7     1171
# 8     1002
# 9      875
# 10     815
# 11     732
# 12     661
# 13     584
# 14     553
# 15     507
# 16     464
# 17     457
# 18     430
# 19     394
# 20     417
# 21     331
# 22     316
# 23     290
# 24     210
# 25     114
# 26      77
# 27      40
# 28      14
# 29       8
# Name: num_intersection, dtype: int64

# %%
trn_df.query('not manual_equal_selected')[['text', 'sentiment', 'manual_selected_text', 'selected_text_lower', 'predicted_texts']]
# Out:
#                                                     text sentiment  \
# 18            is back home now      gonna miss every one  negative
# 27     On the way to Malaysia...no internet access to...  negative
# 32      If it is any consolation I got my BMI tested ...  negative
# 39     A little happy for the wine jeje ok it`sm my f...  positive
# 48     i donbt like to peel prawns, i also dont like ...  negative
# ...                                                  ...       ...
# 27455     i wanna leave work already! Not feelin it 2day  negative
# 27469   lol i know  and haha..did you fall asleep?? o...  negative
# 27473  So I get up early and I feel good about the da...  positive
# 27475   wish we could come see u on Denver  husband l...  negative
# 27479     All this flirting going on - The ATG smiles...   neutral
#
#                                     manual_selected_text  \
# 18                                                <s> is
# 27                                        ...no internet
# 32        ed well so much for being unhappy for about 10
# 39                                    <s> a little happy
# 48                                        also dont like
# ...                                                  ...
# 27455                                 i wanna leave work
# 27469                                          get bored
# 27473                                    and i feel good
# 27475                                       husband lost
# 27479   <s> all this flirting going on - the atg smil...
#
#                                      selected_text_lower  \
# 18                                                  onna
# 27                                          .no internet
# 32      well so much for being unhappy for about 10 m...
# 39                                     a little happy fo
# 48                                          dont like go
# ...                                                  ...
# 27455                                wanna leave work al
# 27469                                            t bored
# 27473                                     i feel good ab
# 27475                                             d lost
# 27479   all this flirting going on - the atg smiles. ...
#
#                                          predicted_texts
# 18                                                  miss
# 27                            no internet access to twit
# 32                                               unhappy
# 39                                                 happy
# 48                                          i donbt like
# ...                                                  ...
# 27455                                 not feelin it 2day
# 27469                                              bored
# 27473                                               good
# 27475                                               lost
# 27479   all this flirting going on - the atg smiles. ...
#
# [2650 rows x 5 columns]

# %%
del ckpts
gc.collect()
# Out:
# 40

# %% [markdown]
# ## パターンをしぼりだす
#  - 原因
#      -
#  - 影響
#      - 合う部分が一つもなくて、default の best_matched_i = 0 が使われている

# %% [markdown]
# #### <s\>, </s\>  を含む場合 (これはどうにか除去しないと...)
# 786     <s> flew brisbane - lax today. great flight. ...
# 808                                              <s> yes
# 852                            <s> i would slip and fall
# 871                                          <s> awesome
# 930                                            <s> happy
# 962                              <s> mad the rain got me
# 1000                                                 <s>
# 1059    <s> omnomnom just came online to 69 unread em...
# 1115                 <s> what?? nooooooooo there goes my
# 1116                     <s> good days with good friends
# 1136    <s> i am jealous...ur koi fish are getting ur...
# 1158                                          <s> is sad
# 1318                  <s> shoesshoesshoes.yayyayyay.lol.
# 1362    <s> hey i loved acs but i had to see it onlin...
# 1375                                      <s> that would
# 1419            <s> me too haha i did but have no credit
# 1514          <s> you can have ice cream, i`ll have kiss
# 1622    <s> copy & paste **** **** tosser piss flap a...
# 1647                              <s> you make me happy,
# 1727                                               <s> o
# 1738                                 <s> very bad things
# 1753    <s> i can`t has blocked me. i can`t even request
# 1797                                                 <s>
# 1821                      <s> thursday night was amazing
# 1827                                 <s> i cant to sleep
# 1849                                          <s> i hate
# 2179    <s> if you`ve ever seen the way uses his brow...
# 2285                                    <s> you`re right
# 2287                                <s> people are cruel
# 2391    <s> i love all my friends and drew were fun t...
# 2558                         <s> i don`t know what to do
# 2597                                      <s> cool sound
# 2695    <s> heading home from sacramento. will contin...
# 2705             <s> i`m not feeling very inspired today
# 2715                                        <s> good tip
# 2742                                        <s> aw honey
# 2786                                        <s> sure! my
# 2788                              <s> i`m really nervous
# 2808                      <s> ...thank you mr. president
# 2956                                            <s> sick
# 3096                                                 <s>
# 3146                               <s> tired as hell!!!!
# 3262                                                 <s>
# 3318                                 <s> missing my hobo
# 3324                                         <s> heading
# 3363    <s> slovakian country side is a refreshing ch...
# 3398    <s> think yourself lucky! i also broke all my...
# 3399                      <s> wow. i hope he gets better
# 3498                                      <s> and thanks
# 3503                                              <s> it
# 3577    <s> seen loads of new photos and stuff of new...
# 3621                                               <s> _
# 3633    <s> re-direct that energy into creating men`s...
# 3668                          <s> seriously getting hurt
# 3707                               <s> back to work i go
# 3806                              <s> man with a kickin`
# 3885                                           <s> thank
# 3936                                        <s> is tired
# 3945                                                 <s>
# 4046                                                 <s>
# 4112    <s> thats actually not that fun as you would ...
# 4147    <s> oh chris, so sorry about mr. raccoon. obv...
# 4264                            <s> what a wonderful day
# 4311    <s> yep, exactly and i`m really sad about thi...
# 4343                                            <s> good
# 4368    <s> more to thank for #ff shouts and heaps mo...
# 4420                                       <s> i love it
# 4485    <s> i cried like a baby when we had to put ou...
# 4542                    <s> omfg whyyyyyy not that sucks
# 4549                                                 <s>
# 4705                                    <s> gud nite all
# 4723                                          <s> whoops
# 4748    <s> you`re welcome! math is really *not* my f...
# 4763                                            <s> well
# 4843                              <s> dinner smells good
# 4868                                          <s> is sad
# 4927    <s> so disappointed with human kind 'what`s w...
# 5188                                         <s> http://
# 5196                                 <s> blahh i`m tired
# 5355                                              <s> is
# 5357                                         <s> me too.
# 5432                              <s> happy mother`s day
# 5435                                                 <s>
# 5602                                  <s> i`m sooo happy
# 5619                                                 <s>
# 23830                                              loves
# 23838                                      not impressed
# 23988                    you can save it for next time!!
# 24025                                             joking
# 24086                                               ****
# 24180                                               luv.
# 24199                                               hate
# 24209                                         byeeeee!!!
# 24271                              hope you have a great
# 24338                                              lucky
# 24379                                      i am so sorry
# 24441                                       feeling nice
# 24504                                             thanks
# 24596   be sure to go by my blog today - and check ou...
# 24622                                            i blame
# 24632                                             awsome
# 24661                                                fun
# 24681                                       interesting.
# 24708                      i havent laid my verse yet...
# 24752                                              happy
# 24777                                               good
# 24908   that is the 3rd nkotb contest that canadians ...
# 24928                                                wow
# 24950                                               good
# 24965   you looked great for being sick yesterday! i`...
# 24979                                            excited
# 24995                         you deserve so much better
# 25103                                            aw poor
# 25283                                             gutted
# 25379   feels slightly better but **** i sure do miss...
# 25399                                  homework...boring
# 25485   feeling better - did nothing yesterday but la...
# 25498                                             missed
# 25511   tanya is jealous because i`m mike`s new favor...
# 25531                                            ****...
# 25592                                          fantastic
# 25596                                              great
# 25721                                               good
# 25724           lol he does love spahkly gold things....
# 25731          soooooooo what happened to power forreal?
# 25752                                               best
# 25759                                               love
# 25946   woot! lol it`s gonna be hard to send this one...
# 25995   poor stuart... i was wondering where he was! ...
# 26076                     doesn`t want to go to work....
# 26111                omg that little girl on bgt!!!!!!!!
# 26200                                              tired
# 26203                                                luv
# 26267                                              sorry
# 26433                                           congrats
# 26459                                        interesting
# 26566   well, i was under the impression most people ...
# 26595                                             hahaha
# 26632                                            slammed
# 26642   one day my hugs will come *fingers still cros...
# 26676                                               glad
# 26686   does anyone out there want to be really aweso...
# 26714                                              tired
# 26759                                     i can`t say no
# 26829                                              broke
# 26869   will do it in a couple od days , when i have ...
# 26926                                              happy
# 26975                           i can`t apologise enough
# 27110   haha, it`ll be gross by the time it comes bac...
# 27120                                            nervous
# 27208                                            failed!
# 27331   haha i see im so bored rite now.. it seems li...
# 27375                                              happy
# 27385                                         appreciate
# 27479   all this flirting going on - the atg smiles. ...

# %%
trn_df.loc[4046].selected_text
# Out:
# 'Unfortunately'

# %%
trn_df.loc[4046].text
# Out:
# 'Well on a normal day I`d already be done with work...Unfortunately this is not a normal day. Which means I`ll be in the office till late.'

# %%
(trn_df.predicted_texts == '').sum()
# Out:
# 180

# %%
trn_df[trn_df['manual_selected_text'].str.contains('</s>').fillna(False)]
# Out:
#            textID                                               text  \
# 7441   d12148ecc8                     I need a wardrobe intervention
# 7836   b30b442df8   invite sent   You can now invite more collabs...
# 15164  feb7ba9cc1   hehe i will never thorw out these shoes  i`m ...
#
#                                            selected_text sentiment  \
# 7441                       I need a wardrobe interventio   neutral
# 7836   invite sent   You can now invite more collabs ...   neutral
# 15164  hehe i will never thorw out these shoes  i`m l...  positive
#
#                                          predicted_texts  \
# 7441                      i need a wardrobe intervention
# 7836    invite sent you can now invite more collabs t...
# 15164                                            awesome
#
#                                     manual_selected_text  unknown_nums  \
# 7441              <s> i need a wardrobe intervention</s>           0.0
# 7836    <s> invite sent you can now invite more colla...           0.0
# 15164   <s> hehe i will never thorw out these shoes i...           0.0
#
#                                      selected_text_lower  \
# 7441                       i need a wardrobe interventio
# 7836    invite sent you can now invite more collabs t...
# 15164   hehe i will never thorw out these shoes i`m l...
#
#        manual_equal_selected
# 7441                   False
# 7836                   False
# 15164                  False

# %%
# ちなみに predicted では一つもない
trn_df[trn_df['predicted_texts'].str.contains('<s>').fillna(False)]
# Out:
# Empty DataFrame
# Columns: [textID, text, selected_text, sentiment, predicted_texts, manual_selected_text, unknown_nums, selected_text_lower, manual_equal_selected]
# Index: []

# %%
# ちなみに predicted では一つもない
trn_df[trn_df['predicted_texts'].str.contains('</s>').fillna(False)]
# Out:
# Empty DataFrame
# Columns: [textID, text, selected_text, sentiment, predicted_texts, manual_selected_text, unknown_nums, selected_text_lower, manual_equal_selected]
# Index: []

# %%
# ちなみに、空文字 predict が結構ある
(trn_df.predicted_texts == '').sum()
# Out:
# 180

# %%
tokenizer.encode(' <s> sorry').ids
# Out:
# [28696, 29, 15698, 6661]

# %%
tokenizer.encode(' sorr').ids
# Out:
# [22696, 338]

# %%
tokenizer.encode(' sorry').tokens
# Out:
# ['Ġsorry']

# %%
tokenizer.encode('word instead...and rsvp...sorry i cant come t').tokens
# Out:
# ['Ġword',
#  'Ġinstead',
#  '...',
#  'and',
#  'Ġr',
#  'sv',
#  'p',
#  '...',
#  'sorry',
#  'Ġi',
#  'Ġcant',
#  'Ġcome',
#  'Ġt']

# %%
tokenizer.encode('Well on a normal day I`d already be done with work...Unfortunately this is not a normal day. Which means I`ll be in the office till late.').tokens
# Out:
# ['Ġwell',
#  'Ġon',
#  'Ġa',
#  'Ġnormal',
#  'Ġday',
#  'Ġi',
#  '`',
#  'd',
#  'Ġalready',
#  'Ġbe',
#  'Ġdone',
#  'Ġwith',
#  'Ġwork',
#  '...',
#  'un',
#  'fortunately',
#  'Ġthis',
#  'Ġis',
#  'Ġnot',
#  'Ġa',
#  'Ġnormal',
#  'Ġday',
#  '.',
#  'Ġwhich',
#  'Ġmeans',
#  'Ġi',
#  '`',
#  'll',
#  'Ġbe',
#  'Ġin',
#  'Ġthe',
#  'Ġoffice',
#  'Ġtill',
#  'Ġlate',
#  '.']

# %%
'Well on a normal day I`d already be done with work...Unfortunately this is not a normal day. Which means I`ll be in the office till late.'.split()
# Out:
# ['Well',
#  'on',
#  'a',
#  'normal',
#  'day',
#  'I`d',
#  'already',
#  'be',
#  'done',
#  'with',
#  'work...Unfortunately',
#  'this',
#  'is',
#  'not',
#  'a',
#  'normal',
#  'day.',
#  'Which',
#  'means',
#  'I`ll',
#  'be',
#  'in',
#  'the',
#  'office',
#  'till',
#  'late.']

# %%
roberta_tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# %%
roberta_tokenizer.special_tokens_map
# Out:
# {'bos_token': '<s>',
#  'eos_token': '</s>',
#  'unk_token': '<unk>',
#  'sep_token': '</s>',
#  'pad_token': '<pad>',
#  'cls_token': '<s>',
#  'mask_token': '<mask>'}

# %%
roberta_tokenizer.encode('<unk>')
# Out:
# [0, 3, 2]

# %%
roberta_tokenizer.decode([2])
# Out:
# '</s>'
